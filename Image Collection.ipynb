# %% [markdown]
# # Dependencies

# %%
import cv2 

# for unique ids
import uuid

# to make the directory univerisal 
import os

# Import time
import time

# %% [markdown]
# # Define Images to collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
labels = ['livelong']
number_imgs = 5

# %% [markdown]
# # Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        if cap.isOpened():
            ret, frame = cap.read()
            imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
            cv2.imwrite(imgname, frame)
            cv2.imshow('frame', frame)
            time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4

# %% [markdown]
# # Image labeling

# %%
# using library for labeling the images

# %%
# !pip install --upgrade pyqt5 lxml

# %%
# !pip list

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.0a8341c5-bf89-11ec-a81d-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.0a8341c5-bf89-11ec-a81d-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.0bb7245a-bf89-11ec-9035-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.0bb7245a-bf89-11ec-9035-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.0e1ea8da-bf89-11ec-9018-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.0e1ea8da-bf89-11ec-9018-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.09479707-bf89-11ec-8740-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.09479707-bf89-11ec-8740-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.c8f13478-bf88-11ec-af24-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.c8f13478-bf88-11ec-af24-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\livelong\livelong.ca247a7e-bf88-11ec-abfc-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/livelong/livelong.ca247a7e-bf88-11ec-abfc-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.0cc66a8d-bf76-11ec-92ef-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.0cc66a8d-bf76-11ec-92ef-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.0dfac57a-bf76-11ec-8733-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.0dfac57a-bf76-11ec-8733-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.0f2e7a1a-bf76-11ec-aa55-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.0f2e7a1a-bf76-11ec-aa55-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.1061c322-bf76-11ec-978e-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.1061c322-bf76-11ec-978e-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.1195cf89-bf76-11ec-8422-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.1195cf89-bf76-11ec-8422-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.05aeb838-bf76-11ec-812c-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.05aeb838-bf76-11ec-812c-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.06e24304-bf76-11ec-b629-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.06e24304-bf76-11ec-b629-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.047ac345-bf76-11ec-868e-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.047ac345-bf76-11ec-868e-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.03461b0f-bf76-11ec-a0d1-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.03461b0f-bf76-11ec-a0d1-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.0815686c-bf76-11ec-8a2f-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.0815686c-bf76-11ec-8a2f-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.4f958139-bf76-11ec-a83a-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.4f958139-bf76-11ec-a83a-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.50cdad0b-bf76-11ec-bc04-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.50cdad0b-bf76-11ec-bc04-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.5201a06d-bf76-11ec-9996-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.5201a06d-bf76-11ec-9996-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.53358bfd-bf76-11ec-828c-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.53358bfd-bf76-11ec-828c-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.54691c22-bf76-11ec-b015-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.54691c22-bf76-11ec-b015-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.fa8e8871-bf75-11ec-b8e7-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.fa8e8871-bf75-11ec-b8e7-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.fc3e6f90-bf75-11ec-8eff-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.fc3e6f90-bf75-11ec-8eff-e8d0fcfe8264.xml
# Image:C:\Users\Amr Elsayed\object_detection_project\Tensorflow\workspace\images\collectedimages\thumbsup\thumbsup.fea524be-bf75-11ec-b6aa-e8d0fcfe8264.jpg -> Annotation:C:/Users/Amr Elsayed/object_detection_project/Tensorflow/workspace/images/collectedimages/thumbsup/thumbsup.fea524be-bf75-11ec-b6aa-e8d0fcfe8264.xml
